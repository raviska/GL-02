# %%
 #Graphical User Interface

# %%
#Reference

# %%
#Aws - Aws sagemaker - Documentation - Supplier ----Resultant ---> Confidence

# %%
a = 10

# %%
list1 = [1,2,3,4,5,"Hello", True, 3.5]

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 'Hello', True, 3.5]

# %%
#Mutable  - List, Sets, Dictionaries
#Immutable - Strings, Numerics, Tuples

# %%
#List  = [], Mutable, Heterogenous[Mixed bag elements]
#Dictinaories - {}, key-value
#Sets = {}, ..elements - Unique
#Tuples = (), Immutable
#Strings

# %%
list1[0] = "Python"

# %%
list1
# Out:
# ['Python', 2, 3, 4, 5, 'Hello', True, 3.5]

# %%
#Sequence-DS -- Sequence Operations
#Slicing, Indexing, Concatenations, Membership Testing, Repititions

# %%
l2 = [3,5,7]

# %%
list1+l2
# Out:
# ['Python', 2, 3, 4, 5, 'Hello', True, 3.5, 3, 5, 7]

# %%
#Builtin - DS - 
#type, len, del, pop, discard, append, extend, insert

# %%
100 in list1
# Out:
# False

# %%
10 not in list1
# Out:
# True

# %%
type(list1)
# Out:
# list

# %%
# %time
list1*1000
# Out:
# Wall time: 0 ns
# ['Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
#  3.5,
#  'Python',
#  2,
#  3,
#  4,
#  5,
#  'Hello',
#  True,
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\HP-till September-2020\\My Office\\Project Management\\2020-21\\Training\\GL-2'

# %%
#GUI

# %%
import qtpy

# %%
# !pip install kivy
# Out:
# ...
#   Created wheel for Kivy-Garden: filename=Kivy_Garden-0.1.4-py3-none-any.whl size=4534 sha256=3696a8b47686a5f4dfa0add15d43f79824a8222e059fb2184c1d264bb58764a8
#   Stored in directory: c:\users\ravic\appdata\local\pip\cache\wheels\d2\72\1a\9ddd17f00755707937caa350616965fb3330a6270425f397e6
# Successfully built Kivy-Garden
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\ravic\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import kivy
# Out:
# [WARNING] [Config      ] Older configuration version detected (0 instead of 21)
# [WARNING] [Config      ] Upgrading configuration in progress.
# [INFO   ] [Logger      ] Record log in C:\Users\ravic\.kivy\logs\kivy_21-02-27_0.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.angle" 0.3.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.3.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.3.1
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\ravic\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.8.3 (default, Jul  2 2020, 17:30:36) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\ravic\anaconda3\python.exe"

# %%
#Git?? - git clone ........url...........git

# %%
os.getcwd()
# Out:
# 'D:\\HP-till September-2020\\My Office\\Project Management\\2020-21\\Training\\GL-2'

# %%
os.chdir('D://HP-till September-2020/My Office/Project Management/2020-21/Training/GL-2/data-analysis-using-python/RawData')

# %%
os.getcwd()
# Out:
# 'D:\\HP-till September-2020\\My Office\\Project Management\\2020-21\\Training\\GL-2\\data-analysis-using-python\\RawData'

# %%
import pandas as pd

# %%
#pd.read_csv('autos.csv')

# %%
#DS
#OOPS
#Loops
#CS
#Debugging
#OS
#Environment set up - Django - windows
